# %%
import sys
sys.path.insert(0, '..')

from panoramix import *

# %%
raw_mat_bounds = read_xls_data(file=settings.input_file, sheet_name='2_feasible_mixes', index_col='raw material')

# %%
raw_mat_bounds
# Out:
#                              mass lower  mass upper mass distribution  \
# raw material
# clinker, Portland cement             95         100           uniform
# slag, blast furnace                   0           5           uniform
# silica fume                           0           5           uniform
# pozzolana, natural                    0           5           uniform
# pozzolana, natural calcined           0           5           uniform
# fly ash, siliceous                    0           5           uniform
# fly ash, calcareous                   0           5           uniform
# shale, burnt                          0           5           uniform
# limestone, TOC < 0.5 mass%            0           5           uniform
# limestone, TOC < 0.2 mass%            0           5           uniform
# red mud                               0           5           uniform
# slag, steel                           0           5           uniform
# ...
